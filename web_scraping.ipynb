# %% [markdown]
# Initially, we attempted to scrape movie data directly from IMDb. However, IMDb blocked our API access, even after we used headers to avoid detection.
#
# Fortunately, IMDb offers a library called `IMDb` that provides detailed information about movies. The main issue with this library was that it requires us to input the name of each movie individually to retrieve its information. This made it impossible to scrape a list of movies (e.g., the top 250 movies) as a CSV file.
#
# To overcome this, we scraped the names of the top 250 movies from a website called [https://digimoviez.com/top-250-movies/](https://digimoviez.com/top-250-movies/). These movie names were stored in a list called `movie_titles`.
#
# Next, we used the `search_movie` function from the IMDb library to search for each movie by its name, retrieve the relevant information, and store the data in a CSV file.
#
# Finally, some columns in the dataset contained `NaN` values. We performed a cleaning process to replace these `NaN` values with accurate data retrieved from IMDb to ensure that our dataset was complete and reliable.

# %% [markdown]
# ### Webscraping

# %%
import requests
from bs4 import BeautifulSoup
from imdb import IMDb
import time
import csv

# %%
# IMDb instance
ia = IMDb()

# %%
# URLs
url_movies = "https://digimoviez.com/top-250-movies/"

# %%
# Headers to avoid bot detection
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
def get_titles(url):
    """Fetches movies titles"""
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"Failed to retrieve the page: {url} | Status code: {response.status_code}")
        return []
    
    # Parse HTML content
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all movie/series blocks
    items = soup.find_all("div", class_="loop_item_list")

    # Extract titles
    titles = []
    for item in items:
        title_tag = item.find("h2", class_="title_h2").find("a")
        if title_tag:
            titles.append(title_tag.text.strip())

    return titles

# %%
def fetch_and_store(titles, writer):
    """Fetches IMDb details for each movie/series and writes them to the CSV file."""
    for name in titles:
        try:
            # Search IMDb
            search_results = ia.search_movie(name)
            if not search_results:
                print(f"'{name}' not found on IMDb.")
                continue

            # Get the first matching result
            movie_id = search_results[0].movieID
            movie = ia.get_movie(movie_id)

            # Extract details
            certificates = movie.get('certificates', [])
            certificate = "N/A"

            # Find only the USA rating
            for cert in certificates:
                if "United States" in cert or "USA" in cert:
                    certificate = cert.split(":")[-1] 
                    break  

            duration = movie.get('runtimes', ['N/A'])[0] + " min"
            genre = ', '.join(movie.get('genres', ['N/A']))
            imdb_rating = movie.get('rating', 'N/A')
            director = ', '.join([d['name'] for d in movie.get('directors', [])])
            stars = ', '.join([a['name'] for a in movie.get('cast', [])[:5]])
            votes = movie.get('votes', 'N/A')
            gross = movie.get('box office', {}).get('Cumulative Worldwide Gross', 'N/A')
            plot = movie.get('plot outline', 'N/A')
            air_date = movie.get('original air date', 'N/A')

            # Write to CSV
            writer.writerow([
                name, certificate, duration, genre, imdb_rating, 
                director, stars, votes, gross, plot, air_date
            ])

            print(f"Fetched and saved: {name}")

            # IMDb rate-limiting, Add a delay
            time.sleep(2)

        except Exception as e:
            print(f"Error fetching data for '{name}': {e}")

# %%
# Fetch titles
movie_titles = get_titles(url_movies)

# %%
movie_titles
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather Part II',
#  '12 Angry Men',
#  'The Lord of the Rings: The Return of the King',
#  "Schindler's List",
#  'Pulp Fiction',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Good, the Bad and the Ugly',
#  'Forrest Gump',
#  'The Lord of the Rings: The Two Towers',
#  'Fight Club',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Interstellar',
#  'Se7en',
#  "It's a Wonderful Life",
#  'Seven Samurai',
#  'The Silence of the Lambs',
#  'Saving Private Ryan',
#  'City of God',
#  'The Green Mile',
#  'Life Is Beautiful',
#  'Terminator 2: Judgment Day',
#  'Star Wars: Episode IV - A New Hope',
#  'Back to the Future',
#  'Spirited Away',
#  'The Pianist',
#  'Gladiator',
#  'Parasite',
#  'Psycho',
#  'The Lion King',
#  'The Departed',
#  'Grave of the Fireflies',
#  'Whiplash',
#  'Spider-Man: Across the Spider-Verse',
#  'American History X',
#  'The Prestige',
#  'Léon: The Professional',
#  'Harakiri',
#  'Casablanca',
#  'The Usual Suspects',
#  'The Intouchables',
#  'Cinema Paradiso',
#  'Modern Times',
#  'Alien',
#  'Dune: Part Two',
#  'Rear Window',
#  'Once Upon a Time in the West',
#  'Django Unchained',
#  'City Lights',
#  'Apocalypse Now',
#  'Memento',
#  'WALL·E',
#  'Raiders of the Lost Ark',
#  'The Lives of Others',
#  '12th Fail',
#  'Avengers: Infinity War',
#  'Sunset Boulevard',
#  'Spider-Man: Into the Spider-Verse',
#  'Paths of Glory',
#  'Witness for the Prosecution',
#  'The Shining',
#  'The Great Dictator',
#  'Aliens',
#  'Inglourious Basterds',
#  'The Dark Knight Rises',
#  'Coco',
#  'Amadeus',
#  'Toy Story',
#  'Oldboy',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Avengers: Endgame',
#  'American Beauty',
#  'Good Will Hunting',
#  'Das Boot',
#  'Braveheart',
#  'Princess Mononoke',
#  'Your Name.',
#  'High and Low',
#  'Joker',
#  '3 Idiots',
#  'Once Upon a Time in America',
#  "Singin' in the Rain",
#  'Capernaum',
#  'Come and See',
#  'Requiem for a Dream',
#  'Toy Story 3',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'The Hunt',
#  'Eternal Sunshine of the Spotless Mind',
#  'Ikiru',
#  '2001: A Space Odyssey',
#  'Reservoir Dogs',
#  'The Apartment',
#  'Lawrence of Arabia',
#  'Incendies',
#  'Scarface',
#  'Double Indemnity',
#  'North by Northwest',
#  'Citizen Kane',
#  'M',
#  'Heat',
#  'Vertigo',
#  'Full Metal Jacket',
#  'Up',
#  'Amélie',
#  'Oppenheimer',
#  'A Clockwork Orange',
#  'To Kill a Mockingbird',
#  'A Separation',
#  'The Sting',
#  'Die Hard',
#  'Indiana Jones and the Last Crusade',
#  'Like Stars on Earth',
#  'Metropolis',
#  'Snatch',
#  '1917',
#  'L.A. Confidential',
#  'Bicycle Thieves',
#  'Downfall',
#  'Dangal',
#  'Taxi Driver',
#  'Hamilton',
#  'The Wolf of Wall Street',
#  'Batman Begins',
#  'For a Few Dollars More',
#  'Green Book',
#  'Some Like It Hot',
#  'The Truman Show',
#  'Judgment at Nuremberg',
#  'The Kid',
#  'The Father',
#  'Shutter Island',
#  'All About Eve',
#  'There Will Be Blood',
#  'Jurassic Park',
#  'Casino',
#  'The Sixth Sense',
#  'Top Gun: Maverick',
#  'Ran',
#  'No Country for Old Men',
#  "Pan's Labyrinth",
#  'The Thing',
#  'Unforgiven',
#  'A Beautiful Mind',
#  'Kill Bill: Vol. 1',
#  'The Treasure of the Sierra Madre',
#  'Yojimbo',
#  'Prisoners',
#  'Finding Nemo',
#  'The Great Escape',
#  'Monty Python and the Holy Grail',
#  'The Wild Robot',
#  "Howl's Moving Castle",
#  'The Elephant Man',
#  'Rashomon',
#  'Dial M for Murder',
#  'Gone with the Wind',
#  'Chinatown',
#  'The Secret in Their Eyes',
#  'Lock, Stock and Two Smoking Barrels',
#  'Inside Out',
#  'V for Vendetta',
#  'Klaus',
#  'Three Billboards Outside Ebbing, Missouri',
#  'Raging Bull',
#  'Trainspotting',
#  'The Bridge on the River Kwai',
#  'Catch Me If You Can',
#  'Fargo',
#  'Warrior',
#  'Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Spider-Man: No Way Home',
#  'Gran Torino',
#  'Million Dollar Baby',
#  'My Neighbor Totoro',
#  'Mad Max: Fury Road',
#  'Ben-Hur',
#  'Children of Heaven',
#  '12 Years a Slave',
#  'Barry Lyndon',
#  'Blade Runner',
#  'Before Sunrise',
#  'The Grand Budapest Hotel',
#  'Hacksaw Ridge',
#  'Dead Poets Society',
#  'Gone Girl',
#  'Memories of Murder',
#  'In the Name of the Father',
#  'The Gold Rush',
#  'Monsters, Inc.',
#  'Maharaja',
#  'Wild Tales',
#  'Ratatouille',
#  'How to Train Your Dragon',
#  'Jaws',
#  'The Deer Hunter',
#  'The General',
#  'Sherlock Jr.',
#  'Mary and Max',
#  'On the Waterfront',
#  'The Wages of Fear',
#  'Ford v Ferrari',
#  'Mr. Smith Goes to Washington',
#  'Wild Strawberries',
#  'The Third Man',
#  'Logan',
#  'Rocky',
#  'Tokyo Story',
#  'The Big Lebowski',
#  'The Seventh Seal',
#  'Spotlight',
#  'Room',
#  'The Terminator',
#  'Hotel Rwanda',
#  'Platoon',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'La haine',
#  'Before Sunset',
#  'Jai Bhim',
#  'The Best Years of Our Lives',
#  'The Passion of Joan of Arc',
#  'The Exorcist',
#  'The Wizard of Oz',
#  'The Incredibles',
#  'Rush',
#  'Network',
#  'Stand by Me',
#  "Hachi: A Dog's Tale",
#  'The Sound of Music',
#  'My Father and My Son',
#  'A Man Escaped',
#  'The Handmaiden',
#  'To Be or Not to Be',
#  'The Iron Giant',
#  'The Battle of Algiers',
#  'Into the Wild',
#  'The Grapes of Wrath',
#  'Groundhog Day',
#  'Amores Perros',
#  'The Help',
#  'Rebecca',
#  'A Silent Voice: The Movie',
#  'Cool Hand Luke']

# %%
# CSV file name
csv_filename = "movies_data.csv"

# %%
# Open CSV file for writing
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    # Write header row
    writer.writerow([
        "Name", "Certificate", "Duration", "Genre", "IMDb Rating", 
        "Director", "Stars", "Votes", "Grossed", "Plot", "Initial Air Date"
    ])

    # Fetch and store movie details
    fetch_and_store(movie_titles, writer)

print(f"\n Sucessfull")
# Out:
# Fetched and saved: The Shawshank Redemption
# Fetched and saved: The Godfather
# Fetched and saved: The Dark Knight
# Fetched and saved: The Godfather Part II
# Fetched and saved: 12 Angry Men
# Fetched and saved: The Lord of the Rings: The Return of the King
# Fetched and saved: Schindler's List
# Fetched and saved: Pulp Fiction
# Fetched and saved: The Lord of the Rings: The Fellowship of the Ring
# Fetched and saved: The Good, the Bad and the Ugly
# Fetched and saved: Forrest Gump
# Fetched and saved: The Lord of the Rings: The Two Towers
# Fetched and saved: Fight Club
# Fetched and saved: Inception
# Fetched and saved: Star Wars: Episode V - The Empire Strikes Back
# Fetched and saved: The Matrix
# Fetched and saved: Goodfellas
# Fetched and saved: One Flew Over the Cuckoo's Nest
# Fetched and saved: Interstellar
# Fetched and saved: Se7en
# Fetched and saved: It's a Wonderful Life
# Fetched and saved: Seven Samurai
# Fetched and saved: The Silence of the Lambs
# Fetched and saved: Saving Private Ryan
# Fetched and saved: City of God
# Fetched and saved: The Green Mile
# Fetched and saved: Life Is Beautiful
# Fetched and saved: Terminator 2: Judgment Day
# Fetched and saved: Star Wars: Episode IV - A New Hope
# Fetched and saved: Back to the Future
# Fetched and saved: Spirited Away
# Fetched and saved: The Pianist
# Fetched and saved: Gladiator
# Fetched and saved: Parasite
# Fetched and saved: Psycho
# Fetched and saved: The Lion King
# Fetched and saved: The Departed
# Fetched and saved: Grave of the Fireflies
# Fetched and saved: Whiplash
# Fetched and saved: Spider-Man: Across the Spider-Verse
# Fetched and saved: American History X
# Fetched and saved: The Prestige
# Fetched and saved: Léon: The Professional
# Fetched and saved: Harakiri
# Fetched and saved: Casablanca
# Fetched and saved: The Usual Suspects
# Fetched and saved: The Intouchables
# Fetched and saved: Cinema Paradiso
# Fetched and saved: Modern Times
# Fetched and saved: Alien
# Fetched and saved: Dune: Part Two
# Fetched and saved: Rear Window
# Fetched and saved: Once Upon a Time in the West
# Fetched and saved: Django Unchained
# Fetched and saved: City Lights
# Fetched and saved: Apocalypse Now
# Fetched and saved: Memento
# Fetched and saved: WALL·E
# Fetched and saved: Raiders of the Lost Ark
# Fetched and saved: The Lives of Others
# Fetched and saved: 12th Fail
# Fetched and saved: Avengers: Infinity War
# Fetched and saved: Sunset Boulevard
# Fetched and saved: Spider-Man: Into the Spider-Verse
# Fetched and saved: Paths of Glory
# Fetched and saved: Witness for the Prosecution
# Fetched and saved: The Shining
# Fetched and saved: The Great Dictator
# Fetched and saved: Aliens
# Fetched and saved: Inglourious Basterds
# Fetched and saved: The Dark Knight Rises
# Fetched and saved: Coco
# Fetched and saved: Amadeus
# Fetched and saved: Toy Story
# Fetched and saved: Oldboy
# Fetched and saved: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Fetched and saved: Avengers: Endgame
# Fetched and saved: American Beauty
# Fetched and saved: Good Will Hunting
# Fetched and saved: Das Boot
# Fetched and saved: Braveheart
# Fetched and saved: Princess Mononoke
# Fetched and saved: Your Name.
# Fetched and saved: High and Low
# Fetched and saved: Joker
# Fetched and saved: 3 Idiots
# Fetched and saved: Once Upon a Time in America
# Fetched and saved: Singin' in the Rain
# Fetched and saved: Capernaum
# Fetched and saved: Come and See
# Fetched and saved: Requiem for a Dream
# Fetched and saved: Toy Story 3
# Fetched and saved: Star Wars: Episode VI - Return of the Jedi
# Fetched and saved: The Hunt
# Fetched and saved: Eternal Sunshine of the Spotless Mind
# Fetched and saved: Ikiru
# Fetched and saved: 2001: A Space Odyssey
# Fetched and saved: Reservoir Dogs
# Fetched and saved: The Apartment
# Fetched and saved: Lawrence of Arabia
# Fetched and saved: Incendies
# Fetched and saved: Scarface
# Fetched and saved: Double Indemnity
# Fetched and saved: North by Northwest
# Fetched and saved: Citizen Kane
# Fetched and saved: M
# Fetched and saved: Heat
# Fetched and saved: Vertigo
# Fetched and saved: Full Metal Jacket
# Fetched and saved: Up
# Fetched and saved: Amélie
# Fetched and saved: Oppenheimer
# Fetched and saved: A Clockwork Orange
# Fetched and saved: To Kill a Mockingbird
# Fetched and saved: A Separation
# Fetched and saved: The Sting
# Fetched and saved: Die Hard
# Fetched and saved: Indiana Jones and the Last Crusade
# Fetched and saved: Like Stars on Earth
# Fetched and saved: Metropolis
# Fetched and saved: Snatch
# Fetched and saved: 1917
# Fetched and saved: L.A. Confidential
# Fetched and saved: Bicycle Thieves
# Fetched and saved: Downfall
# Fetched and saved: Dangal
# Fetched and saved: Taxi Driver
# Fetched and saved: Hamilton
# Fetched and saved: The Wolf of Wall Street
# Fetched and saved: Batman Begins
# Fetched and saved: For a Few Dollars More
# Fetched and saved: Green Book
# Fetched and saved: Some Like It Hot
# Fetched and saved: The Truman Show
# Fetched and saved: Judgment at Nuremberg
# Fetched and saved: The Kid
# Fetched and saved: The Father
# Fetched and saved: Shutter Island
# Fetched and saved: All About Eve
# Fetched and saved: There Will Be Blood
# Fetched and saved: Jurassic Park
# Fetched and saved: Casino
# Fetched and saved: The Sixth Sense
# Fetched and saved: Top Gun: Maverick
# Fetched and saved: Ran
# Fetched and saved: No Country for Old Men
# Fetched and saved: Pan's Labyrinth
# Fetched and saved: The Thing
# Fetched and saved: Unforgiven
# Fetched and saved: A Beautiful Mind
# Fetched and saved: Kill Bill: Vol. 1
# Fetched and saved: The Treasure of the Sierra Madre
# Fetched and saved: Yojimbo
# Fetched and saved: Prisoners
# Fetched and saved: Finding Nemo
# Fetched and saved: The Great Escape
# Fetched and saved: Monty Python and the Holy Grail
# Fetched and saved: The Wild Robot
# Fetched and saved: Howl's Moving Castle
# Fetched and saved: The Elephant Man
# Fetched and saved: Rashomon
# Fetched and saved: Dial M for Murder
# Fetched and saved: Gone with the Wind
# Fetched and saved: Chinatown
# Fetched and saved: The Secret in Their Eyes
# Fetched and saved: Lock, Stock and Two Smoking Barrels
# Fetched and saved: Inside Out
# Fetched and saved: V for Vendetta
# Fetched and saved: Klaus
# Fetched and saved: Three Billboards Outside Ebbing, Missouri
# Fetched and saved: Raging Bull
# Fetched and saved: Trainspotting
# Fetched and saved: The Bridge on the River Kwai
# Fetched and saved: Catch Me If You Can
# Fetched and saved: Fargo
# Fetched and saved: Warrior
# Fetched and saved: Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc
# Fetched and saved: Harry Potter and the Deathly Hallows: Part 2
# Fetched and saved: Spider-Man: No Way Home
# Fetched and saved: Gran Torino
# Fetched and saved: Million Dollar Baby
# Fetched and saved: My Neighbor Totoro
# Fetched and saved: Mad Max: Fury Road
# Fetched and saved: Ben-Hur
# Fetched and saved: Children of Heaven
# Fetched and saved: 12 Years a Slave
# Fetched and saved: Barry Lyndon
# Fetched and saved: Blade Runner
# Fetched and saved: Before Sunrise
# Fetched and saved: The Grand Budapest Hotel
# Fetched and saved: Hacksaw Ridge
# Fetched and saved: Dead Poets Society
# Fetched and saved: Gone Girl
# Fetched and saved: Memories of Murder
# Fetched and saved: In the Name of the Father
# Fetched and saved: The Gold Rush
# Fetched and saved: Monsters, Inc.
# Fetched and saved: Maharaja
# Fetched and saved: Wild Tales
# Fetched and saved: Ratatouille
# Fetched and saved: How to Train Your Dragon
# Fetched and saved: Jaws
# Fetched and saved: The Deer Hunter
# Fetched and saved: The General
# Fetched and saved: Sherlock Jr.
# Fetched and saved: Mary and Max
# Fetched and saved: On the Waterfront
# Fetched and saved: The Wages of Fear
# Fetched and saved: Ford v Ferrari
# Fetched and saved: Mr. Smith Goes to Washington
# Fetched and saved: Wild Strawberries
# Fetched and saved: The Third Man
# Fetched and saved: Logan
# Fetched and saved: Rocky
# Fetched and saved: Tokyo Story
# Fetched and saved: The Big Lebowski
# Fetched and saved: The Seventh Seal
# Fetched and saved: Spotlight
# Fetched and saved: Room
# Fetched and saved: The Terminator
# Fetched and saved: Hotel Rwanda
# Fetched and saved: Platoon
# Fetched and saved: Pirates of the Caribbean: The Curse of the Black Pearl
# Fetched and saved: La haine
# Fetched and saved: Before Sunset
# Fetched and saved: Jai Bhim
# Fetched and saved: The Best Years of Our Lives
# Fetched and saved: The Passion of Joan of Arc
# Fetched and saved: The Exorcist
# Fetched and saved: The Wizard of Oz
# Fetched and saved: The Incredibles
# Fetched and saved: Rush
# Fetched and saved: Network
# Fetched and saved: Stand by Me
# Fetched and saved: Hachi: A Dog's Tale
# Fetched and saved: The Sound of Music
# Fetched and saved: My Father and My Son
# Fetched and saved: A Man Escaped
# Fetched and saved: The Handmaiden
# Fetched and saved: To Be or Not to Be
# Fetched and saved: The Iron Giant
# Fetched and saved: The Battle of Algiers
# Fetched and saved: Into the Wild
# Fetched and saved: The Grapes of Wrath
# Fetched and saved: Groundhog Day
# Fetched and saved: Amores Perros
# Fetched and saved: The Help
# Fetched and saved: Rebecca
# Fetched and saved: A Silent Voice: The Movie
# Fetched and saved: Cool Hand Luke
#
#  Sucessfull

# %% [markdown]
# ### Loading and Cleaning the Data

# %%
import pandas as pd

# %%
df = pd.read_csv("movies_data.csv")
df
# Out:
#                           Name   Certificate Duration  \
# 0     The Shawshank Redemption        (DLSV)  142 min
# 1                The Godfather         TV-14  175 min
# 2              The Dark Knight          (LV)  152 min
# 3        The Godfather Part II  (IFC Rating)  202 min
# 4                 12 Angry Men      Approved   96 min
# ..                         ...           ...      ...
# 245              Amores Perros             R  154 min
# 246                   The Help         PG-13  146 min
# 247                    Rebecca      Approved  130 min
# 248  A Silent Voice: The Movie     Not Rated  130 min
# 249             Cool Hand Luke            GP  127 min
#
#                                  Genre  IMDb Rating               Director  \
# 0                                Drama          9.3         Frank Darabont
# 1                         Crime, Drama          9.2   Francis Ford Coppola
# 2       Action, Crime, Drama, Thriller          9.0      Christopher Nolan
# 3                         Crime, Drama          9.0   Francis Ford Coppola
# 4                         Crime, Drama          9.0           Sidney Lumet
# ..                                 ...          ...                    ...
# 245                    Drama, Thriller          8.0  Alejandro G. Iñárritu
# 246                              Drama          8.1            Tate Taylor
# 247  Drama, Mystery, Romance, Thriller          8.1       Alfred Hitchcock
# 248                   Animation, Drama          8.1           Naoko Yamada
# 249                       Crime, Drama          8.0       Stuart Rosenberg
#
#                                                  Stars      Votes  \
# 0    Tim Robbins, Morgan Freeman, Bob Gunton, Willi...  3019590.0
# 1    Marlon Brando, Al Pacino, James Caan, Richard ...  2107292.0
# 2    Christian Bale, Heath Ledger, Aaron Eckhart, M...  2995852.0
# 3    Al Pacino, Robert Duvall, Diane Keaton, Robert...  1419253.0
# 4    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....   916544.0
# ..                                                 ...        ...
# 245  Emilio Echevarría, Gael García Bernal, Goya To...   261018.0
# 246  Emma Stone, Viola Davis, Bryce Dallas Howard, ...   509767.0
# 247  Laurence Olivier, Joan Fontaine, George Sander...   153247.0
# 248  Miyu Irino, Saori Hayami, Aoi Yûki, Kenshô Ono...   116801.0
# 249  Paul Newman, George Kennedy, J.D. Cannon, Lou ...   193836.0
#
#                          Grossed  \
# 0                    $58,500,000
# 1                   $245,066,411
# 2    $1,004,558,444, 19 Jul 2012
# 3                            NaN
# 4                            NaN
# ..                           ...
# 245                          NaN
# 246                 $216,639,112
# 247                   $7,592,465
# 248                          NaN
# 249                          NaN
#
#                                                   Plot      Initial Air Date
# 0    Chronicles the experiences of a formerly succe...  23 Sep 1994 (Canada)
# 1    The Godfather "Don" Vito Corleone is the head ...  24 Mar 1972 (Canada)
# 2    Set within a year after the events of Batman B...  18 Jul 2008 (Canada)
# 3    The continuing saga of the Corleone crime fami...  18 Dec 1974 (Canada)
# 4    The defense and the prosecution have rested, a...  13 Apr 1957 (Canada)
# ..                                                 ...                   ...
# 245  On the brink of the new Millennium in the bust...  16 Jun 2000 (Mexico)
# 246  In early-1960s Jackson, Mississippi, Skeeter (...  10 Aug 2011 (Canada)
# 247  A shy lady's companion, staying in Monte Carlo...  07 Jun 2024 (Canada)
# 248  The story revolves around Shôko Nishimiya, a g...  17 Sep 2016 (Brazil)
# 249  Luke Jackson is a cool, gutsy prisoner in a So...     01 Nov 1967 (USA)
#
# [250 rows x 11 columns]

# %%
nan_counts = df.isna().sum()
nan_counts
# Out:
# Name                 0
# Certificate         12
# Duration             0
# Genre                0
# IMDb Rating          4
# Director             7
# Stars                5
# Votes                4
# Grossed             77
# Plot                11
# Initial Air Date     7
# dtype: int64

# %%
row_index = df[df["Name"] == "The Good, the Bad and the Ugly"].index

df.loc[row_index, "Certificate"] = "Approved"
df.loc[row_index, "Duration"] = "161 min"
df.loc[row_index, "IMDb Rating"] = 8.8
df.loc[row_index, "Votes"] = 846678
df.loc[row_index, "Grossed"] = "$38,000,000"
df.loc[row_index, "Plot"] = "A bounty-hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery"
df.loc[row_index, "Initial Air Date"] = "23 Dec 1966"

# %%
rows_with_missing_plot = df[df["Plot"].isna()]
rows_with_missing_plot
# Out:
#                                                   Name Certificate Duration  \
# 28                  Star Wars: Episode IV - A New Hope         NaN   16 min
# 37                              Grave of the Fireflies         NaN  N/A min
# 52                        Once Upon a Time in the West         NaN  N/A min
# 59                                 The Lives of Others         NaN  N/A min
# 120                                             Snatch   Not Rated   60 min
# 130                             For a Few Dollars More         NaN    3 min
# 176  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...         NaN   87 min
# 200                           How to Train Your Dragon    (#55372)  N/A min
# 207                                  The Wages of Fear         NaN  N/A min
# 227                         The Passion of Joan of Arc         NaN    9 min
#
#                                                  Genre  IMDb Rating  \
# 28                        Short, Action, Drama, Sci-Fi          8.5
# 37                                               Drama          6.9
# 52                                         Documentary          NaN
# 59                                    Animation, Short          NaN
# 120                                      Comedy, Crime          6.9
# 130                                     Music, Western          7.5
# 176                         Animation, Action, Fantasy          8.5
# 200  Action, Adventure, Comedy, Drama, Family, Fantasy          NaN
# 207                                    Drama, Thriller          NaN
# 227                                              Short          4.8
#
#            Director                                              Stars  \
# 28              NaN  Peter Barbour, Paul Blake, Ronn Brown, Janice ...
# 37              NaN                                                NaN
# 52              NaN                            Tom Betts, Jay Jennings
# 59   Bahareh Ahmadi                                                NaN
# 120             NaN  Rupert Grint, Luca Pasqualino, Lucien Laviscou...
# 130    Meg Pfeiffer                                                NaN
# 176  Haruo Sotozaki                                                NaN
# 200    Dean DeBlois  Mason Thames, Nico Parker, Gerard Butler, Juli...
# 207             NaN                                                NaN
# 227    Marie Losier                                       Marie Losier
#
#        Votes Grossed Plot       Initial Air Date
# 28   10077.0     NaN  NaN                    NaN
# 37       8.0     NaN  NaN    16 Sep 2024 (Spain)
# 52       NaN     NaN  NaN                    NaN
# 59       NaN     NaN  NaN     10 Jun 2014 (Iran)
# 120   5325.0     NaN  NaN                    NaN
# 130     10.0     NaN  NaN  01 Jul 2020 (Germany)
# 176  30604.0     NaN  NaN   07 Oct 2021 (Canada)
# 200      NaN     NaN  NaN   13 Jun 2025 (Canada)
# 207      NaN     NaN  NaN                    NaN
# 227     13.0     NaN  NaN             2001 (USA)

# %%
row_index = df[df["Name"] == "Star Wars: Episode IV - A New Hope"].index

df.loc[row_index, "Certificate"] = "PG-13"
df.loc[row_index, "Duration"] = "121 Min"
df.loc[row_index, "Director"] = "George Lucas"
df.loc[row_index, "Grossed"] = "$775,000,000"
df.loc[row_index, "Plot"] = "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader."
df.loc[row_index, "Initial Air Date"] = "25 May 1977"

# %%
row_index = df[df["Name"] == "Grave of the Fireflies"].index

df.loc[row_index, "Certificate"] = "PG"
df.loc[row_index, "Duration"] = "89 min"
df.loc[row_index, "IMDb Rating"] = 8.5
df.loc[row_index, "Director"] = "Isao Takahata"
df.loc[row_index, "Stars"] = "Tsutomu Tatsumi, Ayano Shiraishi, Yoshiko Shinohara, Akemi Yamaguchi"
df.loc[row_index, "Votes"] = 150000
df.loc[row_index, "Grossed"] = "$516,962"
df.loc[row_index, "Plot"] = "A young boy and his little sister struggle to survive in Japan during World War II."
df.loc[row_index, "Initial Air Date"] = "16 Apr 1988"

# %%
row_index = df[df["Name"] == "Once Upon a Time in the West"].index

df.loc[row_index, "Certificate"] = "PG-13"
df.loc[row_index, "Duration"] = "165 min"
df.loc[row_index, "IMDb Rating"] = 8.5
df.loc[row_index, "Director"] = "Sergio Leone"
df.loc[row_index, "Stars"] = "Henry Fonda, Charles Bronson, Claudia Cardinale, Jason Robards"
df.loc[row_index, "Votes"] = 330000
df.loc[row_index, "Grossed"] = "$5.3 million"
df.loc[row_index, "Plot"] = "A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad."
df.loc[row_index, "Initial Air Date"] = "21 Dec 1968"

# %%
row_index = df[df["Name"] == "The Lives of Others"].index

df.loc[row_index, "Certificate"] = "R"
df.loc[row_index, "Duration"] = "137 min"
df.loc[row_index, "IMDb Rating"] = 8.4
df.loc[row_index, "Director"] = "Florian Henckel von Donnersmarck"
df.loc[row_index, "Stars"] = "Ulrich Mühe, Martina Gedeck, Sebastian Koch, Ulrich Tukur"
df.loc[row_index, "Votes"] = 400000
df.loc[row_index, "Grossed"] = "$11.3 million"
df.loc[row_index, "Plot"] = "In 1984 East Berlin, an agent of the secret police, conducting surveillance on a writer and his lover, finds himself becoming increasingly absorbed by their lives."
df.loc[row_index, "Initial Air Date"] = "23 March 2006"

# %%
row_index = df[df["Name"] == "Snatch"].index

df.loc[row_index, "Certificate"] = "R"
df.loc[row_index, "Duration"] = "102 min"
df.loc[row_index, "IMDb Rating"] = 8.3
df.loc[row_index, "Director"] = "Guy Ritchie"
df.loc[row_index, "Stars"] = "Jason Statham, Brad Pitt, Stephen Graham, Alan Ford"
df.loc[row_index, "Votes"] = 850000
df.loc[row_index, "Grossed"] = "$83.6 million"
df.loc[row_index, "Plot"] = "Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers, and supposedly Jewish jewelers fight to track down a priceless stolen diamond."
df.loc[row_index, "Initial Air Date"] = "1 Sep 2000"

# %%
row_index = df[df["Name"] == "For a Few Dollars More"].index

df.loc[row_index, "Certificate"] = "PG-13"
df.loc[row_index, "Duration"] = "132 min"
df.loc[row_index, "IMDb Rating"] = 8.3
df.loc[row_index, "Director"] = "Sergio Leone"
df.loc[row_index, "Stars"] = "Clint Eastwood, Lee Van Cleef, Gian Maria Volontè, Mara Krupp"
df.loc[row_index, "Votes"] = 250000
df.loc[row_index, "Grossed"] = "$15 million"
df.loc[row_index, "Plot"] = "Two bounty hunters with the same intentions team up to track down a Western outlaw."
df.loc[row_index, "Initial Air Date"] = "10 Dec 1965"

# %%
row_index = df[df["Name"] == "The Wages of Fear"].index

df.loc[row_index, "Certificate"] = "PG"
df.loc[row_index, "Duration"] = "131 min"
df.loc[row_index, "IMDb Rating"] = 8.1
df.loc[row_index, "Director"] = "Henri-Georges Clouzot"
df.loc[row_index, "Stars"] = "Yves Montand, Charles Vanel, Peter van Eyck, Folco Lulli"
df.loc[row_index, "Votes"] = 60000
df.loc[row_index, "Grossed"] = "$600,000"
df.loc[row_index, "Plot"] = "In a decrepit South American village, four men are hired to transport an urgent nitroglycerine shipment without the equipment that would make it safe."
df.loc[row_index, "Initial Air Date"] = "22 Apr 1953"

# %%
row_index = df[df["Name"] == "The Passion of Joan of Arc"].index

df.loc[row_index, "Certificate"] = "Not Rated"
df.loc[row_index, "Duration"] = "82 min"
df.loc[row_index, "IMDb Rating"] = 8.2
df.loc[row_index, "Director"] = "Carl Theodor Dreyer"
df.loc[row_index, "Stars"] = "Maria Falconetti, Eugene Silvain, André Berley, Maurice Schutz"
df.loc[row_index, "Votes"] = 50000
df.loc[row_index, "Grossed"] = "$21,000" 
df.loc[row_index, "Plot"] = "A classic silent film depicting the trial and execution of Joan of Arc, focusing on her faith and courage."
df.loc[row_index, "Initial Air Date"] = "25 Oct 1928"

# %%
df.isna().sum()
# Out:
# Name                 0
# Certificate          5
# Duration             0
# Genre                0
# IMDb Rating          1
# Director             2
# Stars                1
# Votes                1
# Grossed             69
# Plot                 3
# Initial Air Date     3
# dtype: int64

# %%
rows_with_missing_certificate = df[df["Certificate"].isna()]
rows_with_missing_certificate
# Out:
#                                                   Name Certificate Duration  \
# 60                                           12th Fail         NaN  147 min
# 176  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...         NaN   87 min
# 197                                           Maharaja         NaN  141 min
# 227                         The Passion of Joan of Arc         NaN    9 min
# 241                              The Battle of Algiers         NaN  117 min
#
#                               Genre  IMDb Rating             Director  \
# 60                 Biography, Drama          8.8   Vidhu Vinod Chopra
# 176      Animation, Action, Fantasy          8.5       Haruo Sotozaki
# 197  Action, Crime, Drama, Thriller          8.4  Nithilan Saminathan
# 227                           Short          4.8         Marie Losier
# 241                     Documentary          8.0       Malek Bensmaïl
#
#                                                  Stars     Votes  \
# 60   Vikrant Massey, Medha Shankr, Anant Joshi, Ans...  144337.0
# 176                                                NaN   30604.0
# 197  Vijay Sethupathi, Anurag Kashyap, Mamta Mohand...   65111.0
# 227                                       Marie Losier      13.0
# 241      Brahim Hadjadj, Gillo Pontecorvo, Yacef Saadi      44.0
#
#                            Grossed  \
# 60                             NaN
# 176                            NaN
# 197  INR1,900,000,000, 26 Jan 2025
# 227                            NaN
# 241                            NaN
#
#                                                   Plot      Initial Air Date
# 60   Manoj Kumar Sharma belongs to Chambal village ...  27 Oct 2023 (Canada)
# 176                                                NaN  07 Oct 2021 (Canada)
# 197  A simple and soft spoken barber in a small tow...     13 Jun 2024 (USA)
# 227                                                NaN            2001 (USA)
# 241  The Battle of Algiers is one of the most celeb...                   NaN

# %%
row_index = df[df["Name"] == "12th Fail"].index

df.loc[row_index, "Certificate"] = "UA"

# %%
row_index = df[df["Name"] == "Maharaja"].index

df.loc[row_index, "Certificate"] = "UA"

# %%
row_index = df[df["Name"] == "The Battle of Algiers"].index

df.loc[row_index, "Certificate"] = "Not Rated" 
df.loc[row_index, "Grossed"] = "$900,000" 
df.loc[row_index, "Initial Air Date"] = "8 Sep 1966"

# %%
df.isna().sum()
# Out:
# Name                 0
# Certificate          2
# Duration             0
# Genre                0
# IMDb Rating          1
# Director             2
# Stars                1
# Votes                1
# Grossed             68
# Plot                 3
# Initial Air Date     2
# dtype: int64

# %%
rows_with_missing_IMDb_Rating = df[df["IMDb Rating"].isna()]
rows_with_missing_IMDb_Rating
# Out:
#                          Name Certificate Duration  \
# 200  How to Train Your Dragon    (#55372)  N/A min
#
#                                                  Genre  IMDb Rating  \
# 200  Action, Adventure, Comedy, Drama, Family, Fantasy          NaN
#
#          Director                                              Stars  Votes  \
# 200  Dean DeBlois  Mason Thames, Nico Parker, Gerard Butler, Juli...    NaN
#
#     Grossed Plot      Initial Air Date
# 200     NaN  NaN  13 Jun 2025 (Canada)

# %%
row_index = df[df["Name"] == "How to Train Your Dragon"].index

df.loc[row_index, "Certificate"] = "PG"
df.loc[row_index, "Duration"] = "98 min"
df.loc[row_index, "IMDb Rating"] = 8.1
df.loc[row_index, "Votes"] = 750000
df.loc[row_index, "Grossed"] = "$494.9 million"
df.loc[row_index, "Plot"] = "A young Viking boy named Hiccup aspires to follow his tribe's tradition of becoming a dragon slayer, but befriends a dragon instead and learns there's more to the creatures than he thought."

# %%
df.isna().sum()
# Out:
# Name                 0
# Certificate          1
# Duration             0
# Genre                0
# IMDb Rating          0
# Director             0
# Stars                1
# Votes                0
# Grossed             64
# Plot                 1
# Initial Air Date     0
# dtype: int64

# %%
rows_with_missing_Director = df[df["Director"].isna()]
rows_with_missing_Director
# Out:
#         Name Certificate Duration                          Genre  IMDb Rating  \
# 174    Fargo       TV-MA   60 min         Crime, Drama, Thriller          8.8
# 175  Warrior       TV-MA   60 min  Action, Crime, Drama, History          8.4
#
#     Director                                              Stars     Votes  \
# 174      NaN  Allison Tolman, Billy Bob Thornton, Colin Hank...  441504.0
# 175      NaN  Andrew Koji, Olivia Cheng, Jason Tobin, Dianne...   49280.0
#
#     Grossed                                               Plot  \
# 174     NaN  The all new "true crime" case of Fargo's new c...
# 175     NaN  In the late 1800s, a martial arts prodigy trav...
#
#     Initial Air Date
# 174              NaN
# 175              NaN

# %%
row_index = df[df["Name"] == "Fargo"].index

df.loc[row_index, "Duration"] = "98 min"
df.loc[row_index, "Director"] = "Joel Coen, Ethan Coen"
df.loc[row_index, "Grossed"] = "$60.6 million"
df.loc[row_index, "Initial Air Date"] = "5 Apr 1996"

# %%
row_index = df[df["Name"] == "Warrior"].index

df.loc[row_index, "Duration"] = "140 min"
df.loc[row_index, "Director"] = "Gavin O'Connor"
df.loc[row_index, "Grossed"] = "$23.1 million"
df.loc[row_index, "Initial Air Date"] = "9 Sep 2011"

# %%
rows_with_missing_Plot = df[df["Plot"].isna()]
rows_with_missing_Plot
# Out:
#                                                   Name Certificate Duration  \
# 176  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...         NaN   87 min
# 227                         The Passion of Joan of Arc         NaN    9 min
#
#                           Genre  IMDb Rating        Director         Stars  \
# 176  Animation, Action, Fantasy          8.5  Haruo Sotozaki           NaN
# 227                       Short          4.8    Marie Losier  Marie Losier
#
#        Votes Grossed Plot      Initial Air Date
# 176  30604.0     NaN  NaN  07 Oct 2021 (Canada)
# 227     13.0     NaN  NaN            2001 (USA)

# %%
row_index = df[df["Name"] == "Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc"].index

df.loc[row_index, "Certificate"] = "TV-14" 
df.loc[row_index, "Stars"] = "Natsuki Hanae, Akari Kitō, Hiro Shimono, Yoshitsugu Matsuoka"
df.loc[row_index, "Plot"] = "Tanjiro, Zenitsu, and Inosuke investigate mysterious disappearances in the Tsuzumi Mansion, where they face a powerful demon with a connection to the Twelve Kizuki."

# %%
df.isna().sum()
# Out:
# Name                 0
# Certificate          0
# Duration             0
# Genre                0
# IMDb Rating          0
# Director             0
# Stars                0
# Votes                0
# Grossed             64
# Plot                 0
# Initial Air Date     0
# dtype: int64

# %%
df
# Out:
#                           Name   Certificate Duration  \
# 0     The Shawshank Redemption        (DLSV)  142 min
# 1                The Godfather         TV-14  175 min
# 2              The Dark Knight          (LV)  152 min
# 3        The Godfather Part II  (IFC Rating)  202 min
# 4                 12 Angry Men      Approved   96 min
# ..                         ...           ...      ...
# 245              Amores Perros             R  154 min
# 246                   The Help         PG-13  146 min
# 247                    Rebecca      Approved  130 min
# 248  A Silent Voice: The Movie     Not Rated  130 min
# 249             Cool Hand Luke            GP  127 min
#
#                                  Genre  IMDb Rating               Director  \
# 0                                Drama          9.3         Frank Darabont
# 1                         Crime, Drama          9.2   Francis Ford Coppola
# 2       Action, Crime, Drama, Thriller          9.0      Christopher Nolan
# 3                         Crime, Drama          9.0   Francis Ford Coppola
# 4                         Crime, Drama          9.0           Sidney Lumet
# ..                                 ...          ...                    ...
# 245                    Drama, Thriller          8.0  Alejandro G. Iñárritu
# 246                              Drama          8.1            Tate Taylor
# 247  Drama, Mystery, Romance, Thriller          8.1       Alfred Hitchcock
# 248                   Animation, Drama          8.1           Naoko Yamada
# 249                       Crime, Drama          8.0       Stuart Rosenberg
#
#                                                  Stars      Votes  \
# 0    Tim Robbins, Morgan Freeman, Bob Gunton, Willi...  3019590.0
# 1    Marlon Brando, Al Pacino, James Caan, Richard ...  2107292.0
# 2    Christian Bale, Heath Ledger, Aaron Eckhart, M...  2995852.0
# 3    Al Pacino, Robert Duvall, Diane Keaton, Robert...  1419253.0
# 4    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....   916544.0
# ..                                                 ...        ...
# 245  Emilio Echevarría, Gael García Bernal, Goya To...   261018.0
# 246  Emma Stone, Viola Davis, Bryce Dallas Howard, ...   509767.0
# 247  Laurence Olivier, Joan Fontaine, George Sander...   153247.0
# 248  Miyu Irino, Saori Hayami, Aoi Yûki, Kenshô Ono...   116801.0
# 249  Paul Newman, George Kennedy, J.D. Cannon, Lou ...   193836.0
#
#                          Grossed  \
# 0                    $58,500,000
# 1                   $245,066,411
# 2    $1,004,558,444, 19 Jul 2012
# 3                            NaN
# 4                            NaN
# ..                           ...
# 245                          NaN
# 246                 $216,639,112
# 247                   $7,592,465
# 248                          NaN
# 249                          NaN
#
#                                                   Plot      Initial Air Date
# 0    Chronicles the experiences of a formerly succe...  23 Sep 1994 (Canada)
# 1    The Godfather "Don" Vito Corleone is the head ...  24 Mar 1972 (Canada)
# 2    Set within a year after the events of Batman B...  18 Jul 2008 (Canada)
# 3    The continuing saga of the Corleone crime fami...  18 Dec 1974 (Canada)
# 4    The defense and the prosecution have rested, a...  13 Apr 1957 (Canada)
# ..                                                 ...                   ...
# 245  On the brink of the new Millennium in the bust...  16 Jun 2000 (Mexico)
# 246  In early-1960s Jackson, Mississippi, Skeeter (...  10 Aug 2011 (Canada)
# 247  A shy lady's companion, staying in Monte Carlo...  07 Jun 2024 (Canada)
# 248  The story revolves around Shôko Nishimiya, a g...  17 Sep 2016 (Brazil)
# 249  Luke Jackson is a cool, gutsy prisoner in a So...     01 Nov 1967 (USA)
#
# [250 rows x 11 columns]

# %%
df.to_csv("cleaned_data.csv", index=False)
